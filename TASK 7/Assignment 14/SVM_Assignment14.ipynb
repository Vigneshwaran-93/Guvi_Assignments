# %%
#Social_Network_Ads.csv

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split      
from sklearn.svm import SVC

# %% [markdown]
# **Importing the dataset**

# %%
df=pd.read_csv("Social_Network_ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x=df[["Age", "EstimatedSalary"]]
y=df["Purchased"]

# %%
x_train,  x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=5)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (300, 2) (100, 2) (300,) (100,)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
func = StandardScaler()
func.fit(x_train)
x_train_std = func.transform(x_train)
x_test_std = func.transform(x_test)

# %% [markdown]
# **Fitting SVM to the Training set**

# %%
cad = SVC(kernel="linear")
cad.fit(x_train_std,y_train)
cad.score(x_test_std,y_test)
# Out:
# 0.85

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred = cad.predict(x_test_std)

# %% [markdown]
# **Making the Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cmatrix = confusion_matrix(y_test, y_pred) 
   
sns.heatmap(cmatrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Visualising the Training set results**

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = x_train_std[:,0]
ys = x_train_std[:,1]
zs = y_train
ax.scatter(xs, ys, zs, s=50,color=['blue' if p==1 else 'green' for p in clf.predict(x_train_std)], alpha=0.6, edgecolors='w')

ax.set_xlabel('Age')
ax.set_ylabel('EstimatedSalary')
ax.set_zlabel('Purchased')
# Out:
# Text(0.5, 0, 'Purchased')

# %% [markdown]
# **Visualising the Test set results**

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = x_test_std[:,0]
ys = x_test_std[:,1]
zs = y_test
ax.scatter(xs, ys, zs, s=50,color=['blue' if p==1 else 'green' for p in y_pred], alpha=0.6, edgecolors='w')

ax.set_xlabel('Age')
ax.set_ylabel('EstimatedSalary')
ax.set_zlabel('Purchased')
# Out:
# Text(0.5, 0, 'Purchased')

# %% [markdown]
# ### Conclusion
# +> The SVM model has been built and the results have been visulaised.
